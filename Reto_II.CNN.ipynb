# %% [markdown]
# <a href="https://colab.research.google.com/github/CanoPablo/Deep_Learning/blob/main/Reto_II.CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data Analysis
import numpy as np
import pandas as pd

# %% [markdown]
# Descomprimo los archivos zip en carpetas.

# %%
#!unzip -u "/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_train_0.zip" -d "/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/Unzip_x_train_0"

# %%
#!unzip -u "/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_train_1.zip" -d "/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/Unzip_x_train_1"

# %%
# !unzip -u "/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_test/x_test.zip" -d "/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_test/Unzip_x_test"

# %% [markdown]
# Genero una nueva carpeta de validación con una selección aleatoria.

# %%
# import os
# import random
# from shutil import copyfile

# # Directorios de las carpetas
# train_folder = "/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_train/defect_not_confirmed/2/"
# val_folder = "/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_val/defect_not_confirmed/"

# # Crear la carpeta de validación si no existe
# if not os.path.exists(val_folder):
#     os.makedirs(val_folder)

# # Número de imágenes a seleccionar para validación
# num_val_images = 1316

# # Obtener la lista de archivos en la carpeta de entrenamiento
# train_files = os.listdir(train_folder)

# # Seleccionar imágenes al azar para validación
# val_files = random.sample(train_files, num_val_images)

# # Mover las imágenes seleccionadas a la carpeta de validación
# for file in val_files:
#     src = os.path.join(train_folder, file)
#     dst = os.path.join(val_folder, file)
#     copyfile(src, dst)

# %%
# Obtener la lista de archivos en la carpeta de entrenamiento
train_files = os.listdir(train_folder)

# %%
print(len(train_files))
# Out:
# 5266

# %%
# # Directorios de las carpetas
# train_folder = "/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_train/defect_not_confirmed/2/"
# val_folder = "/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_val/defect_not_confirmed/"

# # Obtener la lista de archivos copiados en la carpeta de validación
# val_files = os.listdir(val_folder)

# # Eliminar los archivos copiados de la carpeta de entrenamiento original
# for file in val_files:
#     src = os.path.join(train_folder, file)
#     if os.path.exists(src):
#         os.remove(src)
#     else:
#         print(f"El archivo {file} no existe en la carpeta de entrenamiento.")

# print("Archivos eliminados correctamente.")
# Out:
# Archivos eliminados correctamente.

# %% [markdown]
# Ya tenemos las carpetas train, val.
# Falta asiganr las impagenes de la carpeta test a defect/no defect.

# %%
datos = pd.read_csv("/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/Y_Benchmark.csv")

# %%
datos.head()
# Out:
#                            images  labels
# 0  AE00022_095817_00_1_1_2001.jpg       1
# 1  AE00382_081204_00_3_4_2001.jpg       1
# 2  AE00281_235123_00_2_1_2001.jpg       1
# 3  AE00408_051313_00_4_4_2001.jpg       0
# 4  AE00379_034020_00_1_2_2001.jpg       0

# %%
# import os
# import csv
# import shutil

# def separar_imagenes(csv_file, source_folder, destination_folder_1, destination_folder_2):
#     # Crear carpetas de destino si no existen
#     # os.makedirs(destination_folder_1, exist_ok=True)
#     # os.makedirs(destination_folder_2, exist_ok=True)

#     # Leer el archivo CSV
#     with open(csv_file, 'r') as file:
#         reader = csv.reader(file)
#         next(reader)  # Saltar la primera fila si contiene encabezados

#         # Iterar sobre cada fila del archivo CSV
#         for row in reader:
#             images, labels = row

#             # Construir la ruta completa de la imagen
#             ruta_imagen = os.path.join(source_folder, images)

#             # Verificar si la imagen existe en la carpeta de origen
#             if os.path.isfile(ruta_imagen):
#                 # Determinar la carpeta de destino
#                 if labels == "0":
#                     carpeta_destino = destination_folder_1
#                 elif labels == "1":
#                     carpeta_destino = destination_folder_2
#                 else:
#                     print(f"Clase no válida para la imagen {images}.")
#                     continue

#                 # Mover la imagen a la carpeta de destino
#                 shutil.move(ruta_imagen, carpeta_destino)
#                 print(f"Imagen {images} movida a {carpeta_destino}.")
#             else:
#                 print(f"La imagen {images} no se encontró en {source_folder}.")

# # Especifica la ubicación del archivo CSV y las carpetas de origen y destino
# csv_file = '/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/Y_Benchmark.csv'
# source_folder = '/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_test/Unzip_x_test/x_test'
# destination_folder_1 = '/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_test/defect_confirmed_0'
# destination_folder_2 = '/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_test/defect_not_confirmed_1'

# # Llama a la función para separar las imágenes
# separar_imagenes(csv_file, source_folder, destination_folder_1, destination_folder_2)
# Out:
# Imagen AE00022_095817_00_1_1_2001.jpg movida a /content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_test/defect_not_confirmed_1.
# Imagen AE00382_081204_00_3_4_2001.jpg movida a /content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_test/defect_not_confirmed_1.
# Imagen AE00281_235123_00_2_1_2001.jpg movida a /content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_test/defect_not_confirmed_1.
# Imagen AE00408_051313_00_4_4_2001.jpg movida a /content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_test/defect_confirmed_0.
# Imagen AE00379_034020_00_1_2_2001.jpg movida a /content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_test/defect_confirmed_0.
# Imagen AE00343_113752_00_3_2_2001.jpg movida a /content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_test/defect_not_confirmed_1.
# Imagen AE00346_093109_00_3_4_2001.jpg movida a /content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_test/defect_not_confirmed_1.
# ...

# %%
# import os

# # Directorio de las carpetas
# folder_1 = destination_folder_1
# folder_2 = destination_folder_2

# # Contador para las imágenes en cada carpeta
# count_folder_1 = 0
# count_folder_2 = 0

# # Contar imágenes en la primera carpeta
# for filename in os.listdir(folder_1):
#     if filename.endswith('.jpg'):  # Ajusta la extensión según el tipo de imagen
#         count_folder_1 += 1

# # Contar imágenes en la segunda carpeta
# for filename in os.listdir(folder_2):
#     if filename.endswith('.jpg'):  # Ajusta la extensión según el tipo de imagen
#         count_folder_2 += 1

# # Imprimir resultados
# print(f"El número de imágenes en la carpeta 1 es: {count_folder_1}")
# print(f"El número de imágenes en la carpeta 2 es: {count_folder_2}")
# Out:
# El número de imágenes en la carpeta 1 es: 778
# El número de imágenes en la carpeta 2 es: 1210

# %%
#Skimage (Scikit-image): biblioteca para procesamiento de imágenes
from skimage import io  #Modulo para leer una imagen (librería para procesamiento de imagenes)

# %%
# Es importante que la ruta tenga una diagonal al final

nombre_archivo = '1/AE00554_202617_00_4_2_2001.jpg'

ruta = '/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_train/defect_confirmed/'

image = io.imread(ruta + nombre_archivo, as_gray=True)

# %%
# ¿qué tipo de objeto es imagen?
type(image)
# Out:
# numpy.ndarray

# %%
# ¿qué dimensiones tiene imagen?
image.shape
# Out:
# (1995, 1710)

# %% [markdown]
# El shape es de 2 elementos, por lo tanto es una escala de grises.

# %%
io.imshow(image)

# %% [markdown]
# Nuevo tamaño de imagen.

# %%
SIZE = (128, 128)

# %%
# Pytorch
import torch
import torch.optim as optim
import torchvision.transforms as transforms

# %%
transform = transforms.Compose(
    [
        transforms.Grayscale(),
        transforms.Resize(SIZE),
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,)),
    ]
)

# %%
from torchvision.datasets import ImageFolder

# %%
# # Directorio que contiene las imágenes
# directorio_dataset = "/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_train/"

# # Crea un conjunto de datos de imágenes
# dataset = ImageFolder(root=directorio_dataset)

# # Definir el tamaño del conjunto de validación
# val_size = int(0.2 * len(dataset))  # 20% para validación, 80% para entrenamiento

# # Dividir el conjunto de datos en entrenamiento y validación
# train_subset, val_subset = torch.utils.data.random_split(dataset, [len(dataset) - val_size, val_size])

# # Accede al mapeo de clase a índice
# class_to_idx = dataset.class_to_idx

# # Imprime el mapeo de clase a índice
# print(class_to_idx)
# Out:
# {'defect_confirmed': 0, 'defect_not_confirmed': 1}

# %%
# from collections import Counter

# # Obtener los índices de los datos de entrenamiento
# train_indices = train_subset.indices

# # Obtener las etiquetas del conjunto de datos original usando los índices
# train_labels = [dataset.targets[idx] for idx in train_indices]

# # Contar las etiquetas utilizando Counter
# label_counts_train = Counter(train_labels)

# print(label_counts_train)
# Out:
# Counter({1: 5249, 0: 3239})

# %%
# # Obtener los índices de los datos de entrenamiento
# val_indices = val_subset.indices

# # Obtener las etiquetas del conjunto de datos original usando los índices
# val_labels = [dataset.targets[idx] for idx in val_indices]

# # Contar las etiquetas utilizando Counter
# label_counts_val = Counter(val_labels)

# print(label_counts_val)
# Out:
# Counter({1: 1333, 0: 788})

# %%
type(dataset)
# Out:
# torchvision.datasets.folder.ImageFolder

# %%
from sklearn.model_selection import train_test_split

# %%
# Pytorch
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder

# %%
train_dataset = ImageFolder("/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_train/", transform=transform)
val_dataset = ImageFolder("/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_val/", transform=transform)
test_dataset = ImageFolder("/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_test/", transform=transform)

# %%
val_dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 2121
#     Root location: /content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/x_val/
#     StandardTransform
# Transform: Compose(
#                Grayscale(num_output_channels=1)
#                Resize(size=(128, 128), interpolation=bilinear, max_size=None, antialias=warn)
#                ToTensor()
#                Normalize(mean=(0.5,), std=(0.5,))
#            )

# %%
train_dataset[0][0].shape
# Out:
# torch.Size([1, 128, 128])

# %%
BATCH_SIZE = 128

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
from collections import Counter

print(f"Classes: {train_dataset.class_to_idx}")
num_classes_train = Counter(train_dataset.targets)
num_classes_val = Counter(val_dataset.targets)
print(f"Train Dataset: {num_classes_train}")
print(f"Val Dataset: {num_classes_val}")
# Out:
# Classes: {'defect_confirmed': 0, 'defect_not_confirmed': 1}
# Train Dataset: Counter({1: 5266, 0: 3222})
# Val Dataset: Counter({1: 1316, 0: 805})

# %%
# from torch.utils.data import Dataset

# class CustomDataset(Dataset):
#     def __init__(self, dataset, indices):
#         self.dataset = dataset
#         self.indices = indices

#     def __len__(self):
#         return len(self.indices)

#     def __getitem__(self, idx):
#         # Obtener el índice real en el conjunto de datos original
#         real_idx = self.indices[idx]
#         # Obtener el elemento correspondiente del conjunto de datos original
#         return self.dataset[real_idx]

# # Crear datasets personalizados para train y val
# train_custom_dataset = CustomDataset(directorio_dataset, train_indices)
# val_custom_dataset = CustomDataset(directorio_dataset, val_indices)

# from torch.utils.data import DataLoader

# # Crear DataLoader para el conjunto de datos de entrenamiento
# train_loader = DataLoader(train_custom_dataset, batch_size=BATCH_SIZE, shuffle=True)

# # Crear DataLoader para el conjunto de datos de validación
# val_loader = DataLoader(val_custom_dataset, batch_size=BATCH_SIZE, shuffle=False)


# # Usar ImageFolder con los datasets personalizados
# train_image_folder = ImageFolder(train_custom_dataset, transform=transform)
# val_image_folder = ImageFolder(val_custom_dataset, transform=transform)

# %%
# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Convert dictionaries to ordered lists for plotting
labels = list(num_classes_train.keys())  # Labels are '0' and '1'
train_values = list(num_classes_train.values())
val_values = list(num_classes_val.values())
x_ticks_positions = np.arange(len(labels))  # Positions for labels on the x-axis

# Set up the figure and subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))  # 1 row, 2 columns

# Plot training data on the first subplot
ax1.bar(x_ticks_positions, train_values, color="blue", tick_label=labels)
ax1.set_title("Training Data")
ax1.set_xlabel("Labels")
ax1.set_ylabel("Counts")
ax1.set_ylim(0, max(train_values) * 1.2)  # Set y-axis limit for clarity
ax1.set_xticks([0, 1])  # Set x-axis ticks to only show '0' and '1'

# Plot validation data on the second subplot
ax2.bar(x_ticks_positions, val_values, color="red", tick_label=labels)
ax2.set_title("Validation Data")
ax2.set_xlabel("Labels")
ax2.set_ylabel("Counts")
ax2.set_ylim(
    0, max(val_values) * 1.2
)  # Match y-axis limit with the first plot for consistency
ax2.set_xticks([0, 1])  # Set x-axis ticks to only show '0' and '1'

# Adjust layout for better spacing and display the plot
plt.tight_layout()
plt.show()

# %%
def show_images(num_samples, loader):
    # Initialize lists to hold sampled images and targets
    sampled_images = []
    sampled_targets = []

    # Sample up to num_samples images and targets from the DataLoader
    for images, targets in loader:
        for i in range(images.size(0)):
            sampled_images.append(images[i])
            sampled_targets.append(targets[i])
            if len(sampled_images) >= num_samples:
                break
        if len(sampled_images) >= num_samples:
            break

    # Determine the number of samples actually gathered
    actual_num_samples = len(sampled_images)

    # Setup for subplots based on the actual number of samples
    fig, axes = plt.subplots(
        nrows=1, ncols=actual_num_samples, figsize=(actual_num_samples * 2.5, 2.5)
    )
    if actual_num_samples == 1:
        axes = [axes]  # Making it iterable for consistency

    # Display the sampled images
    for idx, (img, target) in enumerate(zip(sampled_images, sampled_targets)):
        ax = axes[idx]
        img = img.squeeze()  # Assuming grayscale for simplicity
        ax.imshow(img.numpy(), cmap="gray")  # Convert to numpy and display
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"Tag: {target.item()}")

    plt.tight_layout()
    plt.show()

# %%
show_images(8, train_loader)

# %%
show_images(8, val_loader)

# %% [markdown]
# ### Modelo de Redes Convolucionales (CNN Architecture)

# %%
# Pytorch Neural Net
do = 0.3  # Dropout
input = 1 # Grayscale
output = 32
kernel = 3  # 3 Filtros
target = 2  # quiero predecir 2 etiquetas

# %%
from torch.nn import (
    Module,
    Conv2d,
    BatchNorm2d,
    MaxPool2d,
    Dropout2d,
    Linear,
    BatchNorm1d,
    ReLU,
    Dropout,
    CrossEntropyLoss,
)

# %%
class ImageClassifier(Module):
    def __init__(self):
        super().__init__()
        self.conv2D1 = Conv2d(input, output, kernel_size=kernel, padding=0, bias=False)
        self.conv2D2 = Conv2d(
            output, output * 2, kernel_size=kernel, padding=0, bias=False
        )
        self.conv2D3 = Conv2d(
            output * 2, output * 4, kernel_size=kernel, padding=0, bias=False
        )
        self.conv2D4 = Conv2d(
            output * 4, output * 8, kernel_size=kernel, padding=0, bias=False
        )
        self.conv2D5 = Conv2d(
            output * 8, output * 16, kernel_size=kernel, padding=0, bias=False
        )
        self.bn2D1 = BatchNorm2d(output)
        self.bn2D2 = BatchNorm2d(output * 2)
        self.bn2D3 = BatchNorm2d(output * 4)
        self.bn2D4 = BatchNorm2d(output * 8)
        self.bn2D5 = BatchNorm2d(output * 16)
        self.relu = ReLU()
        self.maxpool = MaxPool2d(kernel_size=kernel - 1, stride=2)
        self.dropout2D = Dropout2d(do/2)
        self.dense1 = Linear(2048, output * 8)
        self.dense2 = Linear(output * 8, output * 4)
        self.bn1D1 = BatchNorm1d(output * 8)
        self.bn1D2 = BatchNorm1d(output * 4)
        self.dropout1D = Dropout(do)
        self.dense3 = Linear(output * 4, target)

    def forward(self, x):
        x = self.dropout2D(self.maxpool(self.relu(self.bn2D1(self.conv2D1(x)))))
        x = self.dropout2D(self.maxpool(self.relu(self.bn2D2(self.conv2D2(x)))))
        x = self.dropout2D(self.maxpool(self.relu(self.bn2D3(self.conv2D3(x)))))
        x = self.maxpool(self.relu(self.bn2D4(self.conv2D4(x))))
        x = self.maxpool(self.relu(self.bn2D5(self.conv2D5(x))))
        x = x.view(
            x.shape[0], -1
        )  # Flatten dimensions except batch size to enter to the linear layer
        x = self.dropout1D(self.relu(self.bn1D1(self.dense1(x))))
        x = self.relu(self.bn1D2(self.dense2(x)))
        x = self.dense3(x)

        return x

# %%
import os

# %%
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
# !set 'PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb:2'
torch.cuda.empty_cache()
torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark = False

# %%
if torch.cuda.is_available():
    device = "cuda:0"
else:
    device = "cpu"

# %%
device
# Out:
# 'cpu'

# %%
model = ImageClassifier()
model.to(device)
# Out:
# ImageClassifier(
#   (conv2D1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#   (conv2D2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), bias=False)
#   (conv2D3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), bias=False)
#   (conv2D4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), bias=False)
#   (conv2D5): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), bias=False)
#   (bn2D1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2D2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2D3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2D4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2D5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU()
#   (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ...

# %%
from torchsummary import summary

# %%
summary(model, (1, SIZE[0], SIZE[1]), batch_size=BATCH_SIZE, device="cuda")
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1        [128, 32, 126, 126]             288
#        BatchNorm2d-2        [128, 32, 126, 126]              64
#               ReLU-3        [128, 32, 126, 126]               0
#          MaxPool2d-4          [128, 32, 63, 63]               0
#          Dropout2d-5          [128, 32, 63, 63]               0
#             Conv2d-6          [128, 64, 61, 61]          18,432
#        BatchNorm2d-7          [128, 64, 61, 61]             128
#               ReLU-8          [128, 64, 61, 61]               0
#          MaxPool2d-9          [128, 64, 30, 30]               0
#         Dropout2d-10          [128, 64, 30, 30]               0
#            Conv2d-11         [128, 128, 28, 28]          73,728
#       BatchNorm2d-12         [128, 128, 28, 28]             256
#              ReLU-13         [128, 128, 28, 28]               0
# ...

# %% [markdown]
# ### Entrenamiento

# %%
class EarlyStopping:
    def __init__(self, patience, verbose=False, delta=0, path="checkpoint.pt"):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        return self.early_stop

    def save_checkpoint(self, val_loss, model):
        """Saves model when validation loss decrease."""
        if self.verbose:
            print(
                f"Validation Loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}). Saving model to {self.path}"
            )
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

    def load_checkpoint(self, model):
        """Loads the best model weights from the saved checkpoint."""
        model.load_state_dict(torch.load(self.path))

# %%
# Tunners
LR = 0.0001
EPOCHS = 10

# %%
# Define class frequencies
class_frequencies = torch.tensor(
    [num_classes_train[0], num_classes_train[1]], dtype=torch.float32
)  # Example frequencies for two classes

# Calculate class weights
total_samples = class_frequencies.sum()
class_weights = total_samples / (class_frequencies * len(class_frequencies))
class_weights[0]=class_weights[0]*5 # * 5 Hiperparámetro, esto es por data sets muy desbalanceados, también tengo que pensarlo.
class_weights[1]=class_weights[1]/5 # / 5 Hiperparámetro, esto es por data sets muy desbalanceados, también tengo que pensarlo.

# %%
optimizer = optim.Adam(model.parameters(), lr=LR, amsgrad=True, weight_decay=LR * 0.1)
criterion = CrossEntropyLoss(weight=class_weights).to(device)
early_stopping = EarlyStopping(patience=int(EPOCHS * 0.5), verbose=True)  # Paciencia, Pablo menciona que para un databricks (algo grande) sí tiene sentido detener si no estamos llegando a nada.

# %%
def train_eval(model, loader, optimizer, loss_func, is_training):
    correct = 0
    loss_list = []
    stop = False
    model.train() if is_training else model.eval()

    with torch.set_grad_enabled(is_training):  # Enable gradients only in training
        for batch_idx, (image, target) in tqdm(
            enumerate(loader),
            desc="Epoch_Train" if is_training else "Epoch_Val",
            total=len(loader),
        ):
            image = image.to(device)
            target = target.to(device)
            if is_training:
                optimizer.zero_grad()  # Reset gradients
            output = model(image)
            loss = loss_func(output, target)
            if is_training:
                loss.backward()  # Compute gradients
                optimizer.step()  # Update weights
            loss_list.append(loss.item())
            pred = output.argmax(
                dim=1, keepdim=False
            )  # Get the index of the max log-probability
            correct += pred.eq(target).sum().item()

    if not is_training:
        stop = early_stopping(
            (sum(loss_list) / len(loss_list)), model
        )  # Early stopping decision

    return loss_list, correct, stop

# %%
def calc_acc_loss(total_loss, loss, total_accuracy, correct, loader):
    total_loss.append(sum(loss) / len(loss))
    total_accuracy.append(100 * correct / len(loader.dataset))
    return total_loss, total_accuracy

# %%
# Lists
total_loss_train = []
total_loss_val = []
total_accuracy_train = []
total_accuracy_val = []

# %%
torch.cuda.empty_cache()  # Resetear memoria por si ya ocupamos.
torch.cuda.reset_peak_memory_stats()

# %%
from tqdm.notebook import tqdm

# %%
# %%time
# Training and Evaluation loop
for epoch in range(EPOCHS):
    # Train Iteration
    loss_train, correct_train, _ = train_eval(
        model, train_loader, optimizer, criterion, is_training=True
    )
    # Val Iteration
    loss_val, correct_val, stop = train_eval(
        model, val_loader, optimizer, criterion, is_training=False
    )
    # Calculate and record loss & accuracy for training and validation
    total_loss_train, total_accuracy_train = calc_acc_loss(
        total_loss_train,
        loss_train,
        total_accuracy_train,
        correct_train,
        train_loader,
    )
    # Calculate Loss and Accuracy
    total_loss_val, total_accuracy_val = calc_acc_loss(
        total_loss_val, loss_val, total_accuracy_val, correct_val, val_loader
    )
    # Print metrics per epoch
    print(
        f"Epoch {epoch+1}/{EPOCHS} - Train Loss: {total_loss_train[-1]:.4f}, Val Loss: {total_loss_val[-1]:.4f}, Train Accuracy: {total_accuracy_train[-1]:.2f}%, Val Accuracy: {total_accuracy_val[-1]:.2f}%"
    )
    if stop:
        print("Early Stopping")
        break
# Out:
# ...
# Epoch_Val:   0%|          | 0/17 [00:00<?, ?it/s]
# Validation Loss decreased (inf --> 0.510569). Saving model to checkpoint.pt
# Epoch 1/10 - Train Loss: 0.2411, Val Loss: 0.5106, Train Accuracy: 79.26%, Val Accuracy: 81.47%
# ...
# Epoch_Val:   0%|          | 0/17 [00:00<?, ?it/s]
# Validation Loss decreased (0.510569 --> 0.365700). Saving model to checkpoint.pt
# Epoch 2/10 - Train Loss: 0.1041, Val Loss: 0.3657, Train Accuracy: 81.24%, Val Accuracy: 81.09%
# ...
# Epoch_Val:   0%|          | 0/17 [00:00<?, ?it/s]
# Validation Loss decreased (0.365700 --> 0.151585). Saving model to checkpoint.pt
# Epoch 3/10 - Train Loss: 0.0703, Val Loss: 0.1516, Train Accuracy: 81.94%, Val Accuracy: 97.17%
# ...
# Epoch_Val:   0%|          | 0/17 [00:00<?, ?it/s]
# Validation Loss decreased (0.151585 --> 0.125552). Saving model to checkpoint.pt
# Epoch 4/10 - Train Loss: 0.0513, Val Loss: 0.1256, Train Accuracy: 86.26%, Val Accuracy: 98.02%
# ...
# Epoch_Val:   0%|          | 0/17 [00:00<?, ?it/s]
# ...

# %%
fig, ax1 = plt.subplots(figsize=(7, 7))
ax1.plot(total_loss_train, "b", label="Total Train Loss")
ax1.plot(total_loss_val, "g", label="Total Val Loss")
ax2.set_ylim(0, 5)
ax1.legend(loc=8)
ax2 = ax1.twinx()
ax2.plot(total_accuracy_train, "b", marker="8", label="Total Train Accuracy")
ax2.plot(total_accuracy_val, "g", marker="s", label="Total Val Accuracy")
ax2.set_ylim(0, 100)
ax2.legend(loc=9)
plt.title("CNN Training Convergence", color="black")
ax1.set_xlabel("Training Iterations")
ax1.set_ylabel(f"{criterion._get_name}", color="black")
ax2.set_ylabel("Accuracy (%)", color="black")
plt.show()

# %%
torch.save(model.state_dict(), "/content/drive/MyDrive/Colegio_Bourbaki/Deep_Learning/Semana_2/model_1.pth")

# %% [markdown]
# ### Testing

# %%
torch.cuda.empty_cache()
torch.cuda.reset_peak_memory_stats()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-109-ef665196fb60> in <cell line: 2>()
#       1 torch.cuda.empty_cache()
# ----> 2 torch.cuda.reset_peak_memory_stats()
#
# /usr/local/lib/python3.10/dist-packages/torch/cuda/memory.py in reset_peak_memory_stats(device)
#     305     """
#     306     device = _get_device_index(device, optional=True)
# --> 307     return torch._C._cuda_resetPeakMemoryStats(device)
#     308
#     309
#
# RuntimeError: invalid argument to reset_peak_memory_stats

# %%
model_pred = ImageClassifier()
model_pred.load_state_dict(torch.load("checkpoint.pt"))
model_pred.to(device)
# Out:
# ImageClassifier(
#   (conv2D1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#   (conv2D2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), bias=False)
#   (conv2D3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), bias=False)
#   (conv2D4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), bias=False)
#   (conv2D5): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), bias=False)
#   (bn2D1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2D2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2D3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2D4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2D5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU()
#   (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ...

# %%
def test(model, loader):
    model.eval()
    total_loss_test = []
    test_probs = []
    correct_test = 0
    pred = torch.Tensor().to(device)
    with torch.no_grad():
        for batch_idx, (image, target) in tqdm(
            enumerate(loader), desc="Test Epoch", total=len(loader)
        ):
            image = image.to(device)
            target = target.to(device)
            output = model(image)
            probs = torch.sigmoid(output)
            test_probs.extend(probs.cpu().numpy())
            loss = criterion(output, target)
            total_loss_test.append(loss.item())
            test_pred = output.argmax(dim=1, keepdim=False)
            correct_test += test_pred.eq(target).sum().item()
            pred = torch.cat((pred, test_pred), 0)
        return total_loss_test, correct_test, pred, test_probs

# %%
total_loss_test, correct_test, y_pred, probs_pred = test(model_pred, test_loader)
# Out:
# Test Epoch:   0%|          | 0/16 [00:00<?, ?it/s]

# %% [markdown]
# ### Métricas

# %%
print(f"Classes: {test_dataset.class_to_idx}")
num_classes_test = Counter(test_dataset.targets)

print(f"Test Dataset: {num_classes_test}")
# Out:
# Classes: {'defect_confirmed_0': 0, 'defect_not_confirmed_1': 1}
# Test Dataset: Counter({1: 1210, 0: 778})

# %%
print(f"Loss Test: {(sum(total_loss_test) / len(total_loss_test)):.3f}")
print(f"Test Accuracy: {(100 * correct_test/ len(test_loader.dataset)):.2f} %")
# Out:
# Loss Test: 0.075
# Test Accuracy: 99.35 %

# %%
y_pred = [int(pred) for pred in y_pred.cpu().numpy().tolist()]
prob_list = [list(array) for array in probs_pred]
prob_pos = [prob_list[i][1] for i in range(len(prob_list))]

# %%
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt="g")
    plt.xlabel("Predicted labels")
    plt.ylabel("True labels")
    plt.show()

# %%
# Metrics & Calibration
from sklearn.metrics import (
    confusion_matrix,
    roc_curve,
    auc,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    log_loss,
    brier_score_loss,
    roc_auc_score)

# %%
plot_confusion_matrix(test_dataset.targets, y_pred)

# %%
# Compute ROC curve
fpr, tpr, thresholds = roc_curve(test_dataset.targets, prob_pos)

# Compute Area Under the Curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color="darkorange", lw=2, label=f"ROC curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], color="navy", lw=2, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.show()
